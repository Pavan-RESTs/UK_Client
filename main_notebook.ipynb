# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np
from PIL import Image, ImageDraw, ImageFont

# Step 1: Define the path to your Tamil font
tamil_font_path = r"C:\Users\pavan\StudioProjects\UK_Client\Noto_Sans_Tamil\NIRMALA.TTF"
tamil_font_size = 20

# Load the font using Pillow for text rendering
tamil_font = ImageFont.truetype(tamil_font_path, tamil_font_size)

# Function to create an image for Tamil text
def create_tamil_text_image(text):
    # Create an image with a white background
    img = Image.new('RGBA', (200, 50), (255, 255, 255, 0))
    draw = ImageDraw.Draw(img)
    # Draw the text on the image
    draw.text((0, 0), text, font=tamil_font, fill="black")
    return img

# Step 2: Create data for the pie chart
labels = ['மணல்', 'தண்ணீர்', 'காற்று', 'நெருப்பு']  # Tamil labels
sizes = [30, 40, 20, 10]  # Corresponding sizes
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']

# Step 3: Register the Tamil font with Matplotlib
font_prop = fm.FontProperties(fname=tamil_font_path)

# Step 4: Create the pie chart
fig, ax = plt.subplots(figsize=(6, 6))
wedges, texts, autotexts = ax.pie(sizes, labels=labels, colors=colors, startangle=90)

# Set font properties for labels and title
for text in texts:
    text.set_fontproperties(font_prop)
for autotext in autotexts:
    autotext.set_fontproperties(font_prop)

# Step 5: Set the title with Tamil font
plt.title('வகை சோப்பு', fontproperties=font_prop, fontsize=20)

# Step 6: Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Step 7: Show or save the figure
plt.savefig('tamil_pie_chart_corrected.png', dpi=300, bbox_inches='tight', transparent=True)
plt.show()

# Inform user that the file has been created
print("Pie chart saved as 'tamil_pie_chart_corrected.png'")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 33
#      31 # Step 4: Create the pie chart
#      32 fig, ax = plt.subplots(figsize=(6, 6))
# ---> 33 wedges, texts, autotexts = ax.pie(sizes, labels=labels, colors=colors, startangle=90)
#      35 # Set font properties for labels and title
#      36 for text in texts:
#
# ValueError: not enough values to unpack (expected 3, got 2)
