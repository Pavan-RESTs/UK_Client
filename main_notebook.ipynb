# %%
from PIL import features
features.check("raqm")
# Out:
# True

# %%
from matplotlib import rcParams
import matplotlib
matplotlib.use('module://mplcairo.base')
rcParams['font.family'] = 'Noto Sans Tamil'  


labels = ['எனக்கு', 'ஆப்பிள்', 'திராட்சை', 'கொய்யா']  
sizes = [25, 35, 20, 20]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']


plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)

plt.savefig(r"C:\Users\pavan\Downloads\fgi1", dpi=300, bbox_inches='tight')
plt.axis('equal')
plt.title("கனி வகைகள்", fontsize=14)  
plt.show()
# Out:
# C:\Users\pavan\AppData\Local\Temp\ipykernel_10620\2071196751.py:18: UserWarning: FigureCanvasCairo is non-interactive, and thus cannot be shown
#   plt.show()
